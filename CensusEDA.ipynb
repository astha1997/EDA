# %%
import pandas as pd

# %%
data=pd.read_csv("https://raw.githubusercontent.com/astha1997/EDA/main/census.csv")

# %%
data
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
data.shape
# Out:
# (32561, 15)

# %%
data.head(10)
# Out:
#    age    workclass  fnlwgt     education  education.num marital.status  \
# 0   90            ?   77053       HS-grad              9        Widowed
# 1   82      Private  132870       HS-grad              9        Widowed
# 2   66            ?  186061  Some-college             10        Widowed
# 3   54      Private  140359       7th-8th              4       Divorced
# 4   41      Private  264663  Some-college             10      Separated
# 5   34      Private  216864       HS-grad              9       Divorced
# 6   38      Private  150601          10th              6      Separated
# 7   74    State-gov   88638     Doctorate             16  Never-married
# 8   68  Federal-gov  422013       HS-grad              9       Divorced
# 9   41      Private   70037  Some-college             10  Never-married
#
#           occupation    relationship   race     sex  capital.gain  \
# 0                  ?   Not-in-family  White  Female             0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
#Checking for wrong entries like symbols -,?,#,*,etc.
for col in data :
    print(f" {col} : {data[col].unique()} ")
# Out:
#  age : [90 82 66 54 41 34 38 74 68 45 52 32 51 46 57 22 37 29 61 21 33 49 23 59
#  60 63 53 44 43 71 48 73 67 40 50 42 39 55 47 31 58 62 36 72 78 83 26 70
#  27 35 81 65 25 28 56 69 20 30 24 64 75 19 77 80 18 17 76 79 88 84 85 86
#  87]
#  workclass : ['?' 'Private' 'State-gov' 'Federal-gov' 'Self-emp-not-inc' 'Self-emp-inc'
#  'Local-gov' 'Without-pay' 'Never-worked']
#  fnlwgt : [ 77053 132870 186061 ...  34066  84661 257302]
#  education : ['HS-grad' 'Some-college' '7th-8th' '10th' 'Doctorate' 'Prof-school'
#  'Bachelors' 'Masters' '11th' 'Assoc-acdm' 'Assoc-voc' '1st-4th' '5th-6th'
#  '12th' '9th' 'Preschool']
#  education.num : [ 9 10  4  6 16 15 13 14  7 12 11  2  3  8  5  1]
#  marital.status : ['Widowed' 'Divorced' 'Separated' 'Never-married' 'Married-civ-spouse'
#  'Married-spouse-absent' 'Married-AF-spouse']
#  occupation : ['?' 'Exec-managerial' 'Machine-op-inspct' 'Prof-specialty'
#  'Other-service' 'Adm-clerical' 'Craft-repair' 'Transport-moving'
# ...

# %%
data = data.rename(columns={'native.country': 'native_country'})
data = data.rename(columns={'education.num': 'class'})
data = data.rename(columns={'marital.status': 'marital_status'})
data = data.rename(columns={'capital.loss': 'capital_loss'})
data = data.rename(columns={'capital.gain': 'capital_gain'})
data = data.rename(columns={'hours.per.week': 'hours_per_week'})

# %%
data.describe(include='all')
# Out:
#                  age workclass        fnlwgt education         class  \
# count   32561.000000     32561  3.256100e+04     32561  32561.000000
# unique           NaN         9           NaN        16           NaN
# top              NaN   Private           NaN   HS-grad           NaN
# freq             NaN     22696           NaN     10501           NaN
# mean       38.581647       NaN  1.897784e+05       NaN     10.080679
# std        13.640433       NaN  1.055500e+05       NaN      2.572720
# min        17.000000       NaN  1.228500e+04       NaN      1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN      9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN     10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN     12.000000
# max        90.000000       NaN  1.484705e+06       NaN     16.000000
#
#             marital_status      occupation relationship   race    sex  \
# ...

# %%
import numpy as np
for col in data:
    data[col].replace({'?':np.nan},inplace=True)

# %%
data.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# class                0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     583
# income               0
# dtype: int64

# %%
workclass_mode = data.workclass.mode()[0]

# %%
workclass_mode
# Out:
# 'Private'

# %%
occupation_mode = data.occupation.mode()[0]

# %%
occupation_mode
# Out:
# 'Prof-specialty'

# %%
country_mode = data['native_country'].mode()[0]

# %%
country_mode
# Out:
# 'United-States'

# %%
data.workclass.fillna(workclass_mode, inplace = True)
data.occupation.fillna(occupation_mode, inplace = True)
data.native_country.fillna(country_mode, inplace = True)

# %%
for col in data :
    print(f" {col} : {data[col].unique()} ")
# Out:
#  age : [90 82 66 54 41 34 38 74 68 45 52 32 51 46 57 22 37 29 61 21 33 49 23 59
#  60 63 53 44 43 71 48 73 67 40 50 42 39 55 47 31 58 62 36 72 78 83 26 70
#  27 35 81 65 25 28 56 69 20 30 24 64 75 19 77 80 18 17 76 79 88 84 85 86
#  87]
#  workclass : ['Private' 'State-gov' 'Federal-gov' 'Self-emp-not-inc' 'Self-emp-inc'
#  'Local-gov' 'Without-pay' 'Never-worked']
#  fnlwgt : [ 77053 132870 186061 ...  34066  84661 257302]
#  education : ['HS-grad' 'Some-college' '7th-8th' '10th' 'Doctorate' 'Prof-school'
#  'Bachelors' 'Masters' '11th' 'Assoc-acdm' 'Assoc-voc' '1st-4th' '5th-6th'
#  '12th' '9th' 'Preschool']
#  class : [ 9 10  4  6 16 15 13 14  7 12 11  2  3  8  5  1]
#  marital_status : ['Widowed' 'Divorced' 'Separated' 'Never-married' 'Married-civ-spouse'
#  'Married-spouse-absent' 'Married-AF-spouse']
#  occupation : ['Prof-specialty' 'Exec-managerial' 'Machine-op-inspct' 'Other-service'
#  'Adm-clerical' 'Craft-repair' 'Transport-moving' 'Handlers-cleaners'
# ...

# %% [markdown]
# Education Category

# %%
import matplotlib.pyplot as plt
# Let's calculate the percentage of education  category.
data.education.value_counts(normalize=True)
# Out:
# HS-grad         0.322502
# Some-college    0.223918
# Bachelors       0.164461
# Masters         0.052916
# Assoc-voc       0.042443
# 11th            0.036086
# Assoc-acdm      0.032769
# 10th            0.028654
# 7th-8th         0.019840
# Prof-school     0.017690
# 9th             0.015786
# 12th            0.013298
# Doctorate       0.012684
# 5th-6th         0.010227
# 1st-4th         0.005160
# Preschool       0.001566
# Name: education, dtype: float64

# %%
data.education.value_counts(normalize=True).plot.barh()
plt.show()

# %% [markdown]
# Marital Status

# %%
data.sex.value_counts(normalize=True)
data.sex.value_counts(normalize=True).plot.pie()
plt.show()

# %%
data.race.value_counts(normalize=True)
data.race.value_counts(normalize=True).plot.pie()
plt.show()

# %%
data.income.value_counts(normalize=True)
data.income.value_counts(normalize=True).plot.pie()
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = [ 'relationship', 'occupation','workclass','marital_status']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=data[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
sns.kdeplot(data['hours_per_week'])
# Out:
# <AxesSubplot: xlabel='hours_per_week', ylabel='Density'>

# %%
numeric_features=[feature for feature in data.columns if data[feature].dtype!='O']

# %%
numeric_features
# Out:
# ['age', 'fnlwgt', 'class', 'capital_gain', 'capital_loss', 'hours_per_week']

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_features)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=data[numeric_features[i]],shade=True, color='r')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()
# Out:
# /tmp/ipykernel_77/1431157767.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=data[numeric_features[i]],shade=True, color='r')
# /tmp/ipykernel_77/1431157767.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=data[numeric_features[i]],shade=True, color='r')
# /tmp/ipykernel_77/1431157767.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=data[numeric_features[i]],shade=True, color='r')
# /tmp/ipykernel_77/1431157767.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# ...

# %%
import statistics as st
a=np.array(data['fnlwgt'])

# %%
b=st.quantiles(a,n=10)

# %%
b
# Out:
# [65708.0,
#  106648.0,
#  130856.0,
#  158660.8,
#  178356.0,
#  196338.8,
#  219643.6,
#  259878.4,
#  329058.0]

# %%
    #if i=='<=50K':
        #data['income_2']=0
    #elif i=='>50K':
       # data['income_2']=1
data.loc[data["income"] == '<=50K', "income_2"] = 0

# %%
data.loc[data["income"] == '>50K', "income_2"] = 1

# %%
data.loc[data['fnlwgt'].between(0, 65708.0, 'both'), 'finalweight'] = '0-65708.0'
data.loc[data['fnlwgt'].between(65708.0, 106648.0, 'right'), 'finalweight'] = '65708.0-106648.0'
data.loc[data['fnlwgt'].between(106648.0, 130856.0, 'right'), 'finalweight'] = '106648.0-130856.0'
data.loc[data['fnlwgt'].between(130856.0, 158660.8, 'right'), 'finalweight'] = '130856.0-158660.8'
data.loc[data['fnlwgt'].between(158660.8, 178356.0, 'right'), 'finalweight'] = '158660.8-178356.0'
data.loc[data['fnlwgt'].between(178356.0, 196338.8, 'right'), 'finalweight'] = '178356.0-196338.8'
data.loc[data['fnlwgt'].between(196338.8, 219643.6, 'right'), 'finalweight'] = '196338.8-219643.6'
data.loc[data['fnlwgt'].between(219643.6, 259878.4, 'right'), 'finalweight'] = '219643.6-259878.4'
data.loc[data['fnlwgt'].between(259878.4, 329058.0, 'right'), 'finalweight'] = '259878.4-329058.0'
data.loc[data['fnlwgt'].between(329058.0, 2984705.0, 'right'), 'finalweight'] = '>329058.0'

# %%
data
# Out:
#        age workclass  fnlwgt     education  class      marital_status  \
# 0       90   Private   77053       HS-grad      9             Widowed
# 1       82   Private  132870       HS-grad      9             Widowed
# 2       66   Private  186061  Some-college     10             Widowed
# 3       54   Private  140359       7th-8th      4            Divorced
# 4       41   Private  264663  Some-college     10           Separated
# ...    ...       ...     ...           ...    ...                 ...
# 32556   22   Private  310152  Some-college     10       Never-married
# 32557   27   Private  257302    Assoc-acdm     12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad      9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad      9             Widowed
# 32560   22   Private  201490       HS-grad      9       Never-married
#
#               occupation   relationship   race     sex  capital_gain  \
# ...

# %%
data['income_2'].unique()
# Out:
# array([0., 1.])

# %%
data.groupby(by="finalweight")["income_2"].mean()
# Out:
# finalweight
# 0-65708.0            0.216830
# 106648.0-130856.0    0.257906
# 130856.0-158660.8    0.257529
# 158660.8-178356.0    0.255757
# 178356.0-196338.8    0.250921
# 196338.8-219643.6    0.236794
# 219643.6-259878.4    0.217445
# 259878.4-329058.0    0.221130
# 65708.0-106648.0     0.251765
# >329058.0            0.242015
# Name: income_2, dtype: float64

# %%
data.groupby(by="occupation")["income_2"].mean()
# Out:
# occupation
# Adm-clerical         0.134483
# Armed-Forces         0.111111
# Craft-repair         0.226641
# Exec-managerial      0.484014
# Farming-fishing      0.115694
# Handlers-cleaners    0.062774
# Machine-op-inspct    0.124875
# Other-service        0.041578
# Priv-house-serv      0.006711
# Prof-specialty       0.342637
# Protective-serv      0.325116
# Sales                0.269315
# Tech-support         0.304957
# Transport-moving     0.200376
# Name: income_2, dtype: float64

# %%
import seaborn as sns
sns.barplot(x='income_2',y='occupation',data=data)
# Out:
# <AxesSubplot: xlabel='income_2', ylabel='occupation'>

# %%
import seaborn as sns
sns.barplot(x='income_2',y='sex',data=data)
# Out:
# <AxesSubplot: xlabel='income_2', ylabel='sex'>

# %%
import seaborn as sns
sns.barplot(x='income_2',y='hours_per_week',data=data)
# Out:
# <AxesSubplot: xlabel='income_2', ylabel='hours_per_week'>

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(10,10)})
sns.barplot(x='income_2',y='workclass',data=data)
# Out:
# <AxesSubplot: xlabel='income_2', ylabel='workclass'>

# %%
sns.set(rc={'figure.figsize':(20,30)})
sns.relplot(x='income_2',y='workclass',data=data,style='sex')

# %%
import seaborn as sns
sns.barplot(x='income_2',y='education',data=data)
# Out:
# <AxesSubplot: xlabel='income_2', ylabel='education'>
